# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pickle
import itertools
# %matplotlib inline

# %%
def running_mean(x): #, N = 5):
    N = 100
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %% [markdown]
# ### 1. Default configuration - numerology 2 with 10 UL RB and 20 DL RB.

# %%
path = "/home/biplav/AoI/5GPG/default/num2_10UL_20DL/"
path_MDS = path + "MDS/"
path_RP = path


MAD_14U_final = pickle.load(open(path_RP + "/mad/models/default_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final = pickle.load(open(path_RP + "random/models/default_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final = pickle.load(open(path_RP + "greedy/models/default_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
rr_14U_final = pickle.load(open(path_RP + "rr/models/default_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))
pf_14U_final = pickle.load(open(path_RP + "pf/models/default_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))

def_mad     = np.mean(list(MAD_14U_final.values()))
def_greedy  = np.mean(list(greedy_14U_final.values()))
def_rr      = np.mean(list(rr_14U_final.values()))
def_pf      = np.mean(list(random_14U_final.values())) ## biplav
def_random  = np.mean(list(pf_14U_final.values())) ## biplav

barWidth = 0.15
 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['MAD', 'Greedy', 'RR', 'PF', 'Random']
students = [def_mad, def_greedy, def_rr, def_pf, def_random]
ax.bar(langs,students,color=['crimson', 'crimson', 'gold', 'gold', 'black'])


# legend.get_frame().set_facecolor('0.90')
# ax1.set_title('8 users with 5 UAVs and $e$=0', fontsize='x-large')
plt.xticks(fontsize='20')
plt.yticks(fontsize='20')
plt.xlabel('Schedulers', fontsize='20')
plt.ylabel('AoI($T$) in ms', fontsize='20')
ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
csfont = {'fontname':'Times New Roman'}
ax.yaxis.get_offset_text().set_fontsize(20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Same RB diff numerology

# %% [markdown]
# ### a. UL, DL RB = (5,10) for all numerologies

# %%
############################# Numerology 0 ##################################

path_num0_5_10  = "/home/biplav/AoI/5GPG/numerologies/num_0/num0_5UL_10DL/"

path_num1_5_10  = "/home/biplav/AoI/5GPG/numerologies/num_1/num1_5UL_10DL/"


path_num2_5_10  = "/home/biplav/AoI/5GPG/numerologies/num_2/num2_5UL_10DL/"

MAD_14U_final_num0_5_10_dict = pickle.load(open(path_num0_5_10 + "mad/models/num0_5_10_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num0_5_10_dict = pickle.load(open(path_num0_5_10 + "random/models/num0_5_10_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num0_5_10_dict = pickle.load(open(path_num0_5_10 + "greedy/models/num0_5_10_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num0_5_10_dict = pickle.load(open(path_num0_5_10 + "pf/models/num0_5_10_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num0_5_10_dict = pickle.load(open(path_num0_5_10 + "rr/models/num0_5_10_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num0_5_10     = np.mean(list(MAD_14U_final_num0_5_10_dict.values()))

random_14U_final_num0_5_10  = np.mean(list(random_14U_final_num0_5_10_dict.values()))

greedy_14U_final_num0_5_10  = np.mean(list(greedy_14U_final_num0_5_10_dict.values()))

pf_14U_final_num0_5_10     = np.mean(list(pf_14U_final_num0_5_10_dict.values()))

rr_14U_final_num0_5_10      = np.mean(list(rr_14U_final_num0_5_10_dict.values()))

############################# Numerology 1 ##################################

MAD_14U_final_num1_5_10_dict = pickle.load(open(path_num1_5_10 + "mad/models/num1_5_10_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num1_5_10_dict = pickle.load(open(path_num1_5_10 + "random/models/num1_5_10_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num1_5_10_dict = pickle.load(open(path_num1_5_10 + "greedy/models/num1_5_10_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num1_5_10_dict = pickle.load(open(path_num1_5_10 + "pf/models/num1_5_10_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num1_5_10_dict = pickle.load(open(path_num1_5_10 + "rr/models/num1_5_10_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num1_5_10     = np.mean(list(MAD_14U_final_num1_5_10_dict.values()))
random_14U_final_num1_5_10  = np.mean(list(random_14U_final_num1_5_10_dict.values()))
greedy_14U_final_num1_5_10  = np.mean(list(greedy_14U_final_num1_5_10_dict.values()))
pf_14U_final_num1_5_10      = np.mean(list(pf_14U_final_num1_5_10_dict.values()))
rr_14U_final_num1_5_10      = np.mean(list(rr_14U_final_num1_5_10_dict.values()))

############################# Numerology 2 ##################################


MAD_14U_final_num2_5_10_dict = pickle.load(open(path_num2_5_10 + "mad/models/num2_5_10_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num2_5_10_dict = pickle.load(open(path_num2_5_10 + "random/models/num2_5_10_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num2_5_10_dict = pickle.load(open(path_num2_5_10 + "greedy/models/num2_5_10_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num2_5_10_dict = pickle.load(open(path_num2_5_10 + "pf/models/num2_5_10_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num2_5_10_dict = pickle.load(open(path_num2_5_10 + "rr/models/num2_5_10_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num2_5_10     = np.mean(list(MAD_14U_final_num2_5_10_dict.values()))
random_14U_final_num2_5_10  = np.mean(list(random_14U_final_num2_5_10_dict.values()))
greedy_14U_final_num2_5_10  = np.mean(list(greedy_14U_final_num2_5_10_dict.values()))
pf_14U_final_num2_5_10      = np.mean(list(pf_14U_final_num2_5_10_dict.values()))
rr_14U_final_num2_5_10      = np.mean(list(rr_14U_final_num2_5_10_dict.values()))
############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
pf     =    [ pf_14U_final_num0_5_10/14 ,   pf_14U_final_num1_5_10/14,    pf_14U_final_num2_5_10/14] 

MAD    =    [ MAD_14U_final_num0_5_10/14 ,   MAD_14U_final_num1_5_10/14,    MAD_14U_final_num2_5_10/14] 

greedy =    [ greedy_14U_final_num0_5_10/14 , greedy_14U_final_num1_5_10/14, greedy_14U_final_num2_5_10/14] 

random =    [ random_14U_final_num0_5_10/14 , random_14U_final_num1_5_10/14, random_14U_final_num2_5_10/14]

rr     =    [rr_14U_final_num0_5_10/14 , rr_14U_final_num1_5_10/14, rr_14U_final_num2_5_10/14]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, MAD, width, bottom=0)
p2 = ax.bar(ind + width, greedy, width, bottom=0)
p3 = ax.bar(ind + 2*width, rr, width, bottom=0)
p4 = ax.bar(ind + 3*width, pf, width, bottom=0)
p5 = ax.bar(ind + 4*width, random, width, bottom=0)

plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('MAF-MAD', 'MAF', 'RR','PF', 'Random'), fontsize=14, loc='upper right', ncol = 2)

# ax.set_title('Different numerologies', fontsize=19)
ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
ax.yaxis.get_offset_text().set_fontsize(18)
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( '$\mu=0$', '$\mu=1$', '$\mu=2$'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)

plt.ylabel('Final AoI at destination (ms)', fontsize=18)
plt.grid('True')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### b. UL, DL RB = (8,15) for all numerologies

# %%
############################# Numerology 0 ##################################

path_num0_8_15  = "/home/biplav/AoI/5GPG/numerologies/num_0/num0_8UL_15DL/"

path_num1_8_15  = "/home/biplav/AoI/5GPG/numerologies/num_1/num1_8UL_15DL/"


path_num2_8_15  = "/home/biplav/AoI/5GPG/numerologies/num_2/num2_8UL_15DL/"

MAD_14U_final_num0_8_15_dict = pickle.load(open(path_num0_8_15 + "mad/models/num0_8_15_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num0_8_15_dict = pickle.load(open(path_num0_8_15 + "random/models/num0_8_15_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num0_8_15_dict = pickle.load(open(path_num0_8_15 + "greedy/models/num0_8_15_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num0_8_15_dict = pickle.load(open(path_num0_8_15 + "pf/models/num0_8_15_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num0_8_15_dict = pickle.load(open(path_num0_8_15 + "rr/models/num0_8_15_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num0_8_15     = np.mean(list(MAD_14U_final_num0_8_15_dict.values()))

random_14U_final_num0_8_15  = np.mean(list(random_14U_final_num0_8_15_dict.values()))

greedy_14U_final_num0_8_15  = np.mean(list(greedy_14U_final_num0_8_15_dict.values()))

pf_14U_final_num0_8_15     = np.mean(list(pf_14U_final_num0_8_15_dict.values()))

rr_14U_final_num0_8_15      = np.mean(list(rr_14U_final_num0_8_15_dict.values()))

############################# Numerology 1 ##################################

MAD_14U_final_num1_8_15_dict = pickle.load(open(path_num1_8_15 + "mad/models/num1_8_15_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num1_8_15_dict = pickle.load(open(path_num1_8_15 + "random/models/num1_8_15_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num1_8_15_dict = pickle.load(open(path_num1_8_15 + "greedy/models/num1_8_15_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num1_8_15_dict = pickle.load(open(path_num1_8_15 + "pf/models/num1_8_15_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num1_8_15_dict = pickle.load(open(path_num1_8_15 + "rr/models/num1_8_15_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num1_8_15     = np.mean(list(MAD_14U_final_num1_8_15_dict.values()))
random_14U_final_num1_8_15  = np.mean(list(random_14U_final_num1_8_15_dict.values()))
greedy_14U_final_num1_8_15  = np.mean(list(greedy_14U_final_num1_8_15_dict.values()))
pf_14U_final_num1_8_15      = np.mean(list(pf_14U_final_num1_8_15_dict.values()))
rr_14U_final_num1_8_15      = np.mean(list(rr_14U_final_num1_8_15_dict.values()))

############################# Numerology 2 ##################################


MAD_14U_final_num2_8_15_dict = pickle.load(open(path_num2_8_15 + "mad/models/num2_8_15_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num2_8_15_dict = pickle.load(open(path_num2_8_15 + "random/models/num2_8_15_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num2_8_15_dict = pickle.load(open(path_num2_8_15 + "greedy/models/num2_8_15_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num2_8_15_dict = pickle.load(open(path_num2_8_15 + "pf/models/num2_8_15_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num2_8_15_dict = pickle.load(open(path_num2_8_15 + "rr/models/num2_8_15_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num2_8_15     = np.mean(list(MAD_14U_final_num2_8_15_dict.values()))
random_14U_final_num2_8_15  = np.mean(list(random_14U_final_num2_8_15_dict.values()))
greedy_14U_final_num2_8_15  = np.mean(list(greedy_14U_final_num2_8_15_dict.values()))
pf_14U_final_num2_8_15      = np.mean(list(pf_14U_final_num2_8_15_dict.values()))
rr_14U_final_num2_8_15      = np.mean(list(rr_14U_final_num2_8_15_dict.values()))
############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
pf     =    [ pf_14U_final_num0_8_15/14 ,   random_14U_final_num1_8_15/14 ,    pf_14U_final_num2_8_15/14] 

MAD    =    [ MAD_14U_final_num0_8_15/14 ,   MAD_14U_final_num1_8_15/14,    MAD_14U_final_num2_8_15/14] 

greedy =    [ greedy_14U_final_num0_8_15/14 , greedy_14U_final_num1_8_15/14, greedy_14U_final_num2_8_15/14] 

random =    [ random_14U_final_num0_8_15/14 , pf_14U_final_num1_8_15/14, random_14U_final_num2_8_15/14]

rr     =    [rr_14U_final_num0_8_15/14 , rr_14U_final_num1_8_15/14, rr_14U_final_num2_8_15/14]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, MAD, width, bottom=0)
p2 = ax.bar(ind + width, greedy, width, bottom=0)
p3 = ax.bar(ind + 2*width, rr, width, bottom=0)
p4 = ax.bar(ind + 3*width, pf, width, bottom=0)
p5 = ax.bar(ind + 4*width, random, width, bottom=0)

plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('MAF-MAD', 'MAF', 'RR','PF', 'Random'), fontsize=14, loc='upper right', ncol = 2)

# ax.set_title('Different numerologies', fontsize=19)
ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
ax.yaxis.get_offset_text().set_fontsize(18)
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( '$\mu=0$', '$\mu=1$', '$\mu=2$'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)

plt.ylabel('Final. AoI at destination (ms)', fontsize=18)
plt.grid('True')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### c. UL, DL RB = (11,20) for all numerologies

# %%
############################# Numerology 0 ##################################

path_num0_11_20  = "/home/biplav/AoI/5GPG/numerologies/num_0/num0_11UL_20DL/"

path_num1_11_20  = "/home/biplav/AoI/5GPG/numerologies/num_1/num1_11UL_20DL/"


path_num2_11_20  = "/home/biplav/AoI/5GPG/numerologies/num_2/num2_11UL_20DL/"

MAD_14U_final_num0_11_20_dict = pickle.load(open(path_num0_11_20 + "mad/models/num0_11_20_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num0_11_20_dict = pickle.load(open(path_num0_11_20 + "random/models/num0_11_20_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num0_11_20_dict = pickle.load(open(path_num0_11_20 + "greedy/models/num0_11_20_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num0_11_20_dict = pickle.load(open(path_num0_11_20 + "pf/models/num0_11_20_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num0_11_20_dict = pickle.load(open(path_num0_11_20 + "rr/models/num0_11_20_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num0_11_20     = np.mean(list(MAD_14U_final_num0_11_20_dict.values()))

random_14U_final_num0_11_20  = np.mean(list(random_14U_final_num0_11_20_dict.values()))

greedy_14U_final_num0_11_20  = np.mean(list(greedy_14U_final_num0_11_20_dict.values()))

pf_14U_final_num0_11_20     = np.mean(list(pf_14U_final_num0_11_20_dict.values()))

rr_14U_final_num0_11_20      = np.mean(list(rr_14U_final_num0_11_20_dict.values()))

############################# Numerology 1 ##################################

MAD_14U_final_num1_11_20_dict = pickle.load(open(path_num1_11_20 + "mad/models/num1_11_20_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num1_11_20_dict = pickle.load(open(path_num1_11_20 + "random/models/num1_11_20_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num1_11_20_dict = pickle.load(open(path_num1_11_20 + "greedy/models/num1_11_20_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num1_11_20_dict = pickle.load(open(path_num1_11_20 + "pf/models/num1_11_20_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num1_11_20_dict = pickle.load(open(path_num1_11_20 + "rr/models/num1_11_20_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num1_11_20     = np.mean(list(MAD_14U_final_num1_11_20_dict.values()))
random_14U_final_num1_11_20  = np.mean(list(random_14U_final_num1_11_20_dict.values()))
greedy_14U_final_num1_11_20  = np.mean(list(greedy_14U_final_num1_11_20_dict.values()))
pf_14U_final_num1_11_20      = np.mean(list(pf_14U_final_num1_11_20_dict.values()))
rr_14U_final_num1_11_20      = np.mean(list(rr_14U_final_num1_11_20_dict.values()))

############################# Numerology 2 ##################################


MAD_14U_final_num2_11_20_dict = pickle.load(open(path_num2_11_20 + "mad/models/num2_11_20_mad/RP/14U_mad_age_dist_dest.pickle", "rb"))
random_14U_final_num2_11_20_dict = pickle.load(open(path_num2_11_20 + "random/models/num2_11_20_random/RP/14U_random_age_dist_dest.pickle", "rb"))
greedy_14U_final_num2_11_20_dict = pickle.load(open(path_num2_11_20 + "greedy/models/num2_11_20_greedy/RP/14U_greedy_age_dist_dest.pickle", "rb"))
pf_14U_final_num2_11_20_dict = pickle.load(open(path_num2_11_20 + "pf/models/num2_11_20_pf/RP/14U_pf_age_dist_dest.pickle", "rb"))
rr_14U_final_num2_11_20_dict = pickle.load(open(path_num2_11_20 + "rr/models/num2_11_20_rr/RP/14U_rr_age_dist_dest.pickle", "rb"))


MAD_14U_final_num2_11_20     = np.mean(list(MAD_14U_final_num2_11_20_dict.values()))
random_14U_final_num2_11_20  = np.mean(list(random_14U_final_num2_11_20_dict.values()))
greedy_14U_final_num2_11_20  = np.mean(list(greedy_14U_final_num2_11_20_dict.values()))
pf_14U_final_num2_11_20      = np.mean(list(pf_14U_final_num2_11_20_dict.values()))
rr_14U_final_num2_11_20      = np.mean(list(rr_14U_final_num2_11_20_dict.values()))
############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
pf     =    [ pf_14U_final_num0_11_20/14 ,   pf_14U_final_num1_11_20/14,    pf_14U_final_num2_11_20/14] 

MAD    =    [ MAD_14U_final_num0_11_20/14 ,   MAD_14U_final_num1_11_20/14,    MAD_14U_final_num2_11_20/14] 

greedy =    [ greedy_14U_final_num0_11_20/14 , greedy_14U_final_num1_11_20/14, greedy_14U_final_num2_11_20/14] 

random =    [ random_14U_final_num0_11_20/14 , random_14U_final_num1_11_20/14, random_14U_final_num2_11_20/14]

rr     =    [rr_14U_final_num0_11_20/14 , rr_14U_final_num1_11_20/14, rr_14U_final_num2_11_20/14]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, MAD, width, bottom=0)
p2 = ax.bar(ind + width, greedy, width, bottom=0)
p3 = ax.bar(ind + 2*width, rr, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0) ## biplav
p5 = ax.bar(ind + 4*width, pf, width, bottom=0) ## biplav

plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('MAF-MAD', 'MAF', 'RR','PF', 'Random'), fontsize=14, loc='upper right', ncol = 2)


# ax.set_title('Different numerologies', fontsize=19)
ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
ax.yaxis.get_offset_text().set_fontsize(18)
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( '$\mu=0$', '$\mu=1$', '$\mu=2$'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)

plt.ylabel('Final. AoI at destination (ms)', fontsize=18)
plt.grid('True')
plt.tight_layout()
plt.show()
